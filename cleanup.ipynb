# %%
import re
import pandas as pd
import ast

# %% [markdown]
# # Take a sample from all scraped result

# %%
df1 = pd.read_csv('results_verified_1.csv', header = None)
df2 = pd.read_csv('results_verified_2.csv', header = None)
df3 = pd.read_csv('results_verified_3.csv', header = None)
df4 = pd.read_csv('results_verified_4.csv', header = None)
df5 = pd.read_csv('results_verified_5.csv', header = None)
df__1 = pd.read_csv('results_verified_-1.csv', header = None)
df__2 = pd.read_csv('results_verified_-2.csv', header = None)
df__3 = pd.read_csv('results_verified_-3.csv', header = None)

sample = pd.concat([df1, df2, df3, df4, df5, df__1, df__2, df__3], ignore_index=True)

# %%
sample = sample[[0,1]]

# %%
sample
# Out:
#                         0                                                  1
# 0        Katherine Bukolt                                      ['no result']
# 1         Isaac Greenspan                                      ['no result']
# 2          Carl Malmstrom  ['Carl Malmstrom - Of Counsel - Wolf Haldenste...
# 3        Richard Aaronson  ['Rich Aaronson - Consultant / Social Entrepre...
# 4        Haytham Abu Zayd                                      ['no result']
# ...                   ...                                                ...
# 12548       Graham Bacher                                      ['no result']
# 12549  Rivka Baker Keusch  ['Rikki Baker Keusch - Director of Operations ...
# 12550       Alexander Nye  ['Alex Nye - University of Michigan Law School...
# 12551  Brooke Provinchain                                      ['no result']
# 12552     Michael Sokolow                                      ['no result']
#
# [12553 rows x 2 columns]

# %%
sample.columns = ["Name", "Result"]

# %%
sample
# Out:
#                      Name                                             Result
# 0        Katherine Bukolt                                      ['no result']
# 1         Isaac Greenspan                                      ['no result']
# 2          Carl Malmstrom  ['Carl Malmstrom - Of Counsel - Wolf Haldenste...
# 3        Richard Aaronson  ['Rich Aaronson - Consultant / Social Entrepre...
# 4        Haytham Abu Zayd                                      ['no result']
# ...                   ...                                                ...
# 12548       Graham Bacher                                      ['no result']
# 12549  Rivka Baker Keusch  ['Rikki Baker Keusch - Director of Operations ...
# 12550       Alexander Nye  ['Alex Nye - University of Michigan Law School...
# 12551  Brooke Provinchain                                      ['no result']
# 12552     Michael Sokolow                                      ['no result']
#
# [12553 rows x 2 columns]

# %%
sample
# Out:
#                      Name                                             Result
# 0        Katherine Bukolt                                      ['no result']
# 1         Isaac Greenspan                                      ['no result']
# 2          Carl Malmstrom  ['Carl Malmstrom - Of Counsel - Wolf Haldenste...
# 3        Richard Aaronson  ['Rich Aaronson - Consultant / Social Entrepre...
# 4        Haytham Abu Zayd                                      ['no result']
# ...                   ...                                                ...
# 12548       Graham Bacher                                      ['no result']
# 12549  Rivka Baker Keusch  ['Rikki Baker Keusch - Director of Operations ...
# 12550       Alexander Nye  ['Alex Nye - University of Michigan Law School...
# 12551  Brooke Provinchain                                      ['no result']
# 12552     Michael Sokolow                                      ['no result']
#
# [12553 rows x 2 columns]

# %%
sample.to_csv('results_verify_indicated.csv')

# %%
len(data)
# Out:
# 640

# %%
def edu_or_exp(all_sections):
    educations = []
    experiences = []
    for section in all_sections:
        if 'bachelor' in section or 'master' in section or 'ma, ' in section or 'phd' in section or 'ph.d' in section or 'j.d.' in section or 'juris doctor' in section or 'doctor of medicine' in section or 'mba' in section or 'md' in section or 'high school' in section:
            educations.append(section)
        elif 'show credential\n' in section or 'show project\n' in section or 'show publication\n' in section or '^[0-9]+$ endorsement\n' in section or '^[0-9]+$ endorsements\n' in section or 'recent posts and comments will be displayed here' in section or 'reposted' in section:
            pass
        else:
            experiences.append(section)
    return educations, experiences
def first_break_down(text):
    text = text.split('\n\n\n\n\n\n \n\n \n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n')
    all_sections = []
    delimiters = "\n\n\n\n\n\n \n\n \n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n", '\n\n\n\n\n \n\n \n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n', '\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n'
    regex_pattern = '|'.join(map(re.escape, delimiters))
    for txt in text:
        new_txt = re.split(regex_pattern, txt)
        all_sections.extend(new_txt)
    return all_sections
def further_break_down(sections):
    for section in sections:
        if '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n' in section:
            section_list = section.split('\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n')
            sections.remove(section)
            for sec in experience_list:
                if 'mos' in sec or 'yr' in sec:
                    sections.append(sec)
def same_string(test_str):
    regex = f'{test_str[-2:]}{test_str[0:2]}'
    match = re.search(regex, test_str)
    if match is not None:
        return test_str[match.end()-2:]
def edu_list(educations):
    education_list = []
    for education in educations:
        education_dict = {}
        edu_list = section_summary(education)
        for index, edu in enumerate(edu_list):
            if "(" in edu or ")" in edu:
                new_edu = re.sub(r'\([^)]*\)', '', edu)
                edu_list.remove(edu)
                edu_list.insert(index, new_edu)
        if len(edu_list) > 3:
            education_dict['school'] = same_string(edu_list[0])
            education_dict['degree'] = same_string(edu_list[1])
            education_dict['time'] = same_string(edu_list[2])
            education_list.append(education_dict)
    return education_list

# %%
def section_summary(section):
    delimiters = '\n\n \n\n', " ¬∑ ", "\n\n\n", " · "
    regex_pattern = '|'.join(map(re.escape, delimiters))
    section_detail = re.split(regex_pattern,  section)
    return section_detail
def exp_list(experiences):
    experience_list = []
    regexp = re.compile(r'^[0-9]+$')
    for experience in experiences:
        if experience != '':
            new_experience = ''
            experience_dict = {}
            if "(" in experience or ")" in experience:
                new_experience = re.sub(r'\([^)]*\)', '', experience)
            else:
                new_experience = experience
            exp_list = section_summary(new_experience)
            while '' in exp_list: 
                exp_list.remove('')
            while ' ' in exp_list: 
                exp_list.remove(' ')
            while '\n ' in exp_list: 
                exp_list.remove('\n ')
            if exp_list != []:
                if len(exp_list) > 4:
                    experience_dict['position'] = same_string(exp_list[0])
                    experience_dict['company'] = same_string(exp_list[1])
                    experience_dict['time'] =  exp_list[4]
                    experience_dict['description'] = max(exp_list, key=len)
                    experience_dict['location'] = same_string(exp_list[-1])
                    experience_list.append(experience_dict)
                    if len(experience_list) > 5:
                        break
    return experience_list

# %%
data = {}
for index, alum in sample.iterrows():
    try:
        alum_1 = ast.literal_eval(alum[1])
        for s in alum_1:
            if type(s) is bool:
                alum_1.remove(s)
        if alum_1 != ['no result'] and False not in alum_1 and '\n\n\n\n' in max(alum_1, key=len):
            text = max(alum_1, key=len)
            all_sections = first_break_down(text)
            educations, experiences = edu_or_exp(all_sections)
            education_list = edu_list(educations)
            experience_list = exp_list(experiences)
            data[alum[0]] = {"education": education_list, "experience": experience_list}
    except:
        pass

# %%
data
# Out:
# {'Carl Malmstrom': {'education': [{'school': 'loyola university chicago school of law',
#     'degree': 'j.d.',
#     'time': '2004 - 2007'}],
#   'experience': [{'position': 'wolf haldenstein adler freeman & herz llp',
#     'company': '14 yrs 7 mos',
#     'time': 'full-timefull-time',
#     'description': 'wolf haldenstein adler freeman & herz llpwolf haldenstein adler freeman & herz llp',
#     'location': None},
#    {'position': 'law clerk ',
#     'company': 'city of chicago, department of law',
#     'time': '2 yrs 2 mos',
#     'description': 'city of chicago, department of lawcity of chicago, department of law',
#     'location': None},
#    {'position': 'intern',
#     'company': 'christine cegelis for congress',
#     'time': '7 mos',
#     'description': 'christine cegelis for congresschristine cegelis for congress',
#     'location': None},
#    {'position': 'intern',
#     'company': 'office of cook county commissioner larry suffredin ',
#     'time': '4 mos',
#     'description': 'office of cook county commissioner larry suffredin office of cook county commissioner larry suffredin ',
#     'location': None},
#    {'position': 'graduate teaching assistant',
#     'company': 'university of hawaii at manoa, department of anthropology',
#     'time': '6 mos',
#     'description': 'university of hawaii at manoa, department of anthropologyuniversity of hawaii at manoa, department of anthropology',
#     'location': None},
#    {'position': 'university of chicago',
#     'company': 'm.a., social science ',
#     'time': '\nelizabeth davis-berg has given an endorsement for this skillelizabeth davis-berg has given an endorsement for this skill',
#     'description': '\nelizabeth davis-berg has given an endorsement for this skillelizabeth davis-berg has given an endorsement for this skill',
#     'location': None}]},
#  'Esi Ansah': {'education': [{'school': 'rutgers university - newark',
#     'degree': 'phd, public administration',
#     'time': '2004 - 2008'}],
#   'experience': [{'position': 'ceo & founding partner',
#     'company': 'axis human capital ltd.',
#     'time': '14 yrs 7 mos',
#     'description': "axis human capital ltd. is a human capital development firm that aims to ultimately transform how talent is developed and managed in africa, generating value for our stakeholders.  we were set up in 2008 in ghana, and have grown steadily in delivering lasting solutions to our clients.we have built a reputation for recruiting high-caliber candidates for employers, and working with them to develop their individual and organizational capacity through corporate training, strategic alignment programs, talent management and other interventions. we are especially interested in working with growth-oriented smes  that are interested in building healthy human capital management systems. we work with job seekers to map out their career paths and prepare for career opportunities through personalized career coaching, workshops and cv/bio reviews. we are thorough, and we integrate leadership development in all our work, tailoring our solutions to our clients' short- and long-term needs and strategies. axis human capital ltd. is a human capital development firm that aims to ultimately transform how talent is developed and managed in africa, generating value for our stakeholders.  we were set up in 2008 in ghana, and have grown steadily in delivering lasting solutions to our clients.\n\nwe have built a reputation for recruiting high-caliber candidates for employers, and working with them to develop their individual and organizational capacity through corporate training, strategic alignment programs, talent management and other interventions. \n\nwe are especially interested in working with growth-oriented smes  that are interested in building healthy human capital management systems.   \n\nwe work with job seekers to map out their career paths and prepare for career opportunities through personalized career coaching, workshops and cv/bio reviews. \n\nwe are thorough, and we integrate leadership development in all our work, tailoring our solutions to our clients' short- and long-term needs and strategies. ",
#     'location': None},
#    {'position': 'founder & executive director',
#     'company': "association of ghana's elders ",
#     'time': '9 yrs 2 mos',
#     'description': 'our aim is really very simple. we want to spearhead a movement – a comprehensive, shared journey to build awareness and action, meaningful conversations and engagements around the issues of ageing in ghana and africa at large. we will mobilize all the resources we can, to design creative solutions that make old age enjoyable. the end game is simple – dignified healthy, happy lives as we grow older. age works along three dimensions - policy advocacy, a discount network to negotiate lower prices of products and services to our members and organizing programs to keep    our elders meaningfully engaged.our aim is really very simple. we want to spearhead a movement – a comprehensive, shared journey to build awareness and action, meaningful conversations and engagements around the issues of ageing in ghana and africa at large. we will mobilize all the resources we can, to design creative solutions that make old age enjoyable. the end game is simple – dignified healthy, happy lives as we grow older. \n\nage works along three dimensions - policy advocacy, a discount network to negotiate lower prices of products and services to our members and organizing programs to keep    our elders meaningfully engaged.',
#     'location': None},
#    {'position': 'fellow',
#     'company': 'africa leadership initiative ',
#     'time': '12 yrs 9 mos',
#     'description': 'a network of african leaders who are part of the aspen global leadership network and are working together to move from success to significance.a network of african leaders who are part of the aspen global leadership network and are working together to move from success to significance.',
#     'location': None},
#    {'position': 'founding member',
#     'company': 'association for research on civil society in africa ',
#     'time': '7 yrs 3 mos',
#     'description': 'association for research on civil society in africa association for research on civil society in africa ',
#     'location': None},
#    {'position': 'executive director',
#     'company': 'paul a. v. ansah memorial foundation',
#     'time': '11 yrs 8 mos',
#     'description': 'paul a. v. ansah memorial foundationpaul a. v. ansah memorial foundation',
#     'location': 'accra, ghana'}]},
#  'Meredith Barges': {'education': [{'school': 'yale divinity school',
#     'degree': 'master of divinity - mdiv',
#     'time': '2020 - 2023'},
#    {'school': 'university of chicago',
#     'degree': 'ma, history and social theory',
#     'time': None}],
#   'experience': [{'position': 'researcher, yale bird-friendly building initiative',
#     'company': None,
#     'time': 'jun 2022 - present',
#     'description': 'study the effectiveness of bird-safe building policies toward accelerating the adoption of bird-friendly building policy nationally. examine the push and pulls of bird collision deterrence, particularly in relation to green building and meeting municipal net zero goals. part of the yale bird-friendly building initiative, a grant-funded project co-led by the american bird conservancy, yale law school, the yale peabody museum of natural history, and the yale office of sustainability.study the effectiveness of bird-safe building policies toward accelerating the adoption of bird-friendly building policy nationally. examine the push and pulls of bird collision deterrence, particularly in relation to green building and meeting municipal net zero goals. part of the yale bird-friendly building initiative, a grant-funded project co-led by the american bird conservancy, yale law school, the yale peabody museum of natural history, and the yale office of sustainability.',
#     'location': None},
#    {'position': 'co-chair, lights out connecticut',
#     'company': 'lights out connecticut',
#     'time': '1 yr',
#     'description': 'organize public outreach to build a network of ct residents, businesses, property owners, nonprofits, and local governments who pledge to dim or turn off excess lights at night during peak periods of migration to protect migratory birds. build strategic partnerships with local conservation and wildlife groups. fundraise. raise awareness about the harmful effects of light pollution on birds and other wildlife.organize public outreach to build a network of ct residents, businesses, property owners, nonprofits, and local governments who pledge to dim or turn off excess lights at night during peak periods of migration to protect migratory birds. build strategic partnerships with local conservation and wildlife groups. fundraise. raise awareness about the harmful effects of light pollution on birds and other wildlife.',
#     'location': None},
#    {'position': 'international dark sky advocate',
#     'company': 'international dark-sky association',
#     'time': '1 yr',
#     'description': 'international dark-sky associationinternational dark-sky association',
#     'location': None},
#    {'position': 'senior intern',
#     'company': None,
#     'time': 'jun 2021 - aug 2021',
#     'description': "saw firsthand how urban farms, restorative agriculture, and farm-to-foodshelf programs can build local resilience while reducing food insecurity and addressing the climate crisis. helped produce cr's first strategic plan, edited grant proposals, and co-managed the farmstand at south village and the farmstand at the south burlington food shelf.saw firsthand how urban farms, restorative agriculture, and farm-to-foodshelf programs can build local resilience while reducing food insecurity and addressing the climate crisis. helped produce cr's first strategic plan, edited grant proposals, and co-managed the farmstand at south village and the farmstand at the south burlington food shelf.",
#     'location': None},
#    {'position': 'communications strategist; editor-in-chief',
#     'company': None,
#     'time': 'oct 2019 - dec 2020',
#     'description': 'developed messaging and visibility campaigns for nyu school of nursing, deans, and faculty. placed op eds in leading news outlets, like cnn. co-produced three issues of nyu nursing magazine.developed messaging and visibility campaigns for nyu school of nursing, deans, and faculty. placed op eds in leading news outlets, like cnn. co-produced three issues of nyu nursing magazine.',
#     'location': None},
#    {'position': 'volunteer, patient services',
#     'company': 'yale new haven health',
#     'time': '9 mos',
#     'description': 'volunteer, patient servicesvolunteer, patient services',
#     'location': 'health'}]},
#  'Mingfai Chew': {'education': [{'school': 'national university of singapore',
#     'degree': 'masters in public health',
#     'time': '2017 - 2018'},
#    {'school': 'university of chicago',
#     'degree': 'ma, social sciences',
#     'time': '1997 - 2001'}],
#   'experience': [{'position': 'associate professor ',
#     'company': 'saw swee hock school of public health',
#     'time': '4 mos',
#     'description': 'saw swee hock school of public healthsaw swee hock school of public health',
#     'location': 'singapore'},
#    {'position': 'national environment agency',
#     'company': '4 yrs 7 mos',
#     'time': 'jul 2020 - present',
#     'description': '\ndeputy director-general of public healthdeputy director-general of public health\n\n \n \njan 2019 - may 2019',
#     'location': None},
#    {'position': 'graduate student',
#     'company': 'saw swee hock school of public health',
#     'time': '11 mos',
#     'description': 'saw swee hock school of public healthsaw swee hock school of public health',
#     'location': None},
#    {'position': 'national environment agency',
#     'company': '5 yrs',
#     'time': '7 mos',
#     'description': "responsible for charting the environmental technology roadmap of interest and relevance to nea with guidance from nea board and senior management, and in consultation with nea operation divisions.review and fund r&d efforts in our ihls and companies to support nea's technological needs.plan and implement technology testbeds to validate new technologies in operational conditions.responsible for charting the environmental technology roadmap of interest and relevance to nea with guidance from nea board and senior management, and in consultation with nea operation divisions.\n\nreview and fund r&d efforts in our ihls and companies to support nea's technological needs.\n\nplan and implement technology testbeds to validate new technologies in operational conditions.",
#     'location': None},
#    {'position': 'head, professional services',
#     'company': 'singapore economic development board',
#     'time': '4 yrs 4 mos',
#     'description': 'responsible for the economic development and promotion of the legal, accounting and communications services sectors in singaporeresponsible for the economic development and promotion of the legal, accounting and communications services sectors in singapore',
#     'location': None}]},
#  'Seth Cothrun': {'education': [{'school': 'university of chicago',
#     'degree': "master's degree, anthropology and latin american studies",
#     'time': None},
#    {'school': 'university of arizona',
#     'degree': "bachelor's degree, anthropology and latin american history",
#     'time': None}],
#   'experience': [{'position': 'director, global thematic marketing & franklin templeton institute',
#     'company': None,
#     'time': '2021 - present',
#     'description': "member of core leadership team that developed, launched, and continues to expand franklin templeton thinks, a holistic content strategy designed to addresses the challenges of a large organization with multiple investment teams delivering thoughtful content and investment insights to a global audience. member of franklin templeton institute team, who's mission is to provide our clients with research that meets their needs and concerns. we do this by listening, understanding, and then harnessing the resources of our firm to answer the challenge. we organize around areas of exploration to develop distinct insights and their practical applications.member of core leadership team that developed, launched, and continues to expand franklin templeton thinks, a holistic content strategy designed to addresses the challenges of a large organization with multiple investment teams delivering thoughtful content and investment insights to a global audience. member of franklin templeton institute team, who's mission is to provide our clients with research that meets their needs and concerns. we do this by listening, understanding, and then harnessing the resources of our firm to answer the challenge. we organize around areas of exploration to develop distinct insights and their practical applications.",
#     'location': None},
#    {'position': 'aspen institute fellow',
#     'company': 'the aspen institute',
#     'time': '4 yrs 6 mos',
#     'description': "leadership in launching and streamlining franklin templeton thinks, a holistic content strategy designed to addresses the challenges of a large organization with multiple investment teams delivering thoughtful content to a global audience. the effort champions franklin's opinions and insights to answer marketplace questions and needs. it is holistic in the sense that the program covers a) editorial, b) production; c) promotion; and d) feedback. this new content framework exposes firm views in the most impactful manner: to help clients, investors and their advisors. the efforts are uniquely positioned in the firm as a catalyst and integration point to extend other teams, whether investment or marketing and sales, so franklin's voice will do the most good and we can incorporate the best ideas to share knowledge and expertise.franklin templeton thinks in 2019• 38 newly new articles were written and published in 2019 through the new insights platforms.• globally, articles were published on 33 english language sites and 21 other languages country/audience combinations. content on the 33 english sites was published simultaneously, and the 21 other language sites followed within 2 weeks accounting for time needed to translate content. read: time to market and global reach allowed pieces to be deployed quickly to clients in all regions.sample piece• in the first eight weeks post-release, the piece generated globally 4,458,143 impressions and 306 media placements .• sample of global media placements: bloomberg, china securities journal, east money , hexun , sina , oriental daily news , harvest , citywire , das investment , tribuna , fanews , advisoranalyst.com , analizy , egospodarka leadership in launching and streamlining franklin templeton thinks, a holistic content strategy designed to addresses the challenges of a large organization with multiple investment teams delivering thoughtful content to a global audience. the effort champions franklin's opinions and insights to answer marketplace questions and needs. it is holistic in the sense that the program covers a) editorial, b) production; c) promotion; and d) feedback. this new content framework exposes firm views in the most impactful manner: to help clients, investors and their advisors. the efforts are uniquely positioned in the firm as a catalyst and integration point to extend other teams, whether investment or marketing and sales, so franklin's voice will do the most good and we can incorporate the best ideas to share knowledge and expertise.\n\nfranklin templeton thinks in 2019\n• 38 newly new articles were written and published in 2019 through the new insights platforms.\n• globally, articles were published on 33 english language sites and 21 other languages country/audience combinations. content on the 33 english sites was published simultaneously, and the 21 other language sites followed within 2 weeks accounting for time needed to translate content. read: time to market and global reach allowed pieces to be deployed quickly to clients in all regions.\n\nsample piece\n• in the first eight weeks post-release, the piece generated globally 4,458,143 impressions\n and 306 media placements .\n• sample of global media placements: bloomberg, china securities journal, east money , hexun , sina , oriental daily news , harvest , citywire , das investment , tribuna , fanews , advisoranalyst.com , analizy , egospodarka ",
#     'location': None},
#    {'position': 'high country news',
#     'company': '3 yrs 10 mos',
#     'time': '2 yrs 7 mos',
#     'description': "high country news is the nation's leading source of reporting on the american west. high country news is a nonprofit 5013 independent media organization that covers the important issues and stories that define the american west. our mission is to inform and inspire people – through in-depth journalism – to act on behalf of the west's diverse natural and human communities.high country news is the nation's leading source of reporting on the american west. high country news is a nonprofit 5013 independent media organization that covers the important issues and stories that define the american west. our mission is to inform and inspire people – through in-depth journalism – to act on behalf of the west's diverse natural and human communities.",
#     'location': None},
#    {'position': 'american express leadership academies',
#     'company': '4 yrs 9 mos',
#     'time': '4 yrs 9 mos',
#     'description': 'the committee on innovation & communications focuses on opportunities to expand awareness of the academy; the alumni network; and use platforms such as leaderstories.org to tell success stories and share best practices.• oversaw formation of committee and creation of committee charter.• committee led marketing campaign to name, brand, and launch american expresses newest leadership academy, the converge academy.• committee led creation of working group to conceive, brand, and launch the leadervoices podcast. a new podcast platform focused on bring stories of leadership to alumni of the network.the committee on innovation & communications focuses on opportunities to expand awareness of the academy; the alumni network; and use platforms such as leaderstories.org to tell success stories and share best practices.\n• oversaw formation of committee and creation of committee charter.\n• committee led marketing campaign to name, brand, and launch american expresses newest leadership academy, the converge academy.\n• committee led creation of working group to conceive, brand, and launch the leadervoices podcast. a new podcast platform focused on bring stories of leadership to alumni of the network.',
#     'location': None},
#    {'position': None,
#     'company': None,
#     'time': '\n',
#     'description': 'i recommend seth based on the business manager type role he owned for the ubs americas marketing team.  his efforts in establishing and tracking the budget, as well as being influential in project and headcount management, were of significant impact to the americas region and have set a standard for other areas.  his work ethic and personality contributions will make him an asset to any organization.i recommend seth based on the business manager type role he owned for the ubs americas marketing team.  his efforts in establishing and tracking the budget, as well as being influential in project and headcount management, were of significant impact to the americas region and have set a standard for other areas.  his work ethic and personality contributions will make him an asset to any organization.',
#     'location': None}]},
#  'Brian Cross': {'education': [],
#   'experience': [{'position': 'ubs asset management',
#     'company': '6 yrs 3 mos',
#     'time': '4 yrs 11 mos',
#     'description': "qed's mandate is to drive quant and data science into the traditional fundamental investment process.  our goal is to make data science an essential part of the investment mosaic leveraging alternative data and machine learning. qed's mandate is to drive quant and data science into the traditional fundamental investment process.  our goal is to make data science an essential part of the investment mosaic leveraging alternative data and machine learning. ",
#     'location': None},
#    {'position': 'executive director',
#     'company': "ubs o'connor",
#     'time': '4 yrs 4 mos',
#     'description': 'generalist for equity long/short hedge fund.generalist for equity long/short hedge fund.',
#     'location': None},
#    {'position': 'ubs investment bank',
#     'company': '9 yrs 2 mos',
#     'time': '2 yrs 5 mos',
#     'description': 'etf market maker and principal program trader on program/quant trading desk for ubs ib.etf market maker and principal program trader on program/quant trading desk for ubs ib.',
#     'location': 'etf market maker and principal program trader on program/quant trading desk for ubs ib.'},
#    {'position': 'nirav nimish shah',
#     'company': None,
#     'time': 'in my opinion, nirav was excellent at his job at ubs. nirav and i worked on a leading edge social networking project within the investment bank together. in my opinion, nirav had strong work ethic, vision, and superior technical skills. i would highly recommend nirav.in my opinion, nirav was excellent at his job at ubs. nirav and i worked on a leading edge social networking project within the investment bank together. in my opinion, nirav had strong work ethic, vision, and superior technical skills. i would highly recommend nirav.',
#     'description': 'throughout both the refinance and home purchase process, scott went above and beyond the call of duty to answer all of my questions and go to bat for me with a very competitive rate.  scott is an expert and is very willing to walk you through the mortgage process and answer all of your questions.  for a first time home buyer, i could not have imagined a more rewarding experience than working with scott.  i would certainly use scott again and have recommended him, and will continue to recommended him, to my friends who are also home buyers.throughout both the refinance and home purchase process, scott went above and beyond the call of duty to answer all of my questions and go to bat for me with a very competitive rate.  scott is an expert and is very willing to walk you through the mortgage process and answer all of your questions.  for a first time home buyer, i could not have imagined a more rewarding experience than working with scott.  i would certainly use scott again and have recommended him, and will continue to recommended him, to my friends who are also home buyers.',
#     'location': None}]},
#  'Marcia DaCosta': {'education': [{'school': 'university if chicago',
#     'degree': 'master of arts , social sciences research',
#     'time': '2001 - 2003'},
#    {'school': 'seattle university',
#     'degree': 'bachelor of arts , sociology',
#     'time': None}],
#   'experience': [{'position': None,
#     'company': None,
#     'time': '\n4',
#     'description': ' \n\nwhat an experience management software can do for an airline',
#     'location': None},
#    {'position': 'dynamite magazine',
#     'company': 'dynamo',
#     'time': '30 yrs 1 mo',
#     'description': 'são paulo area, brazilsão paulo area, brazil',
#     'location': 'são paulo area, brazil'},
#    {'position': 'panel manager',
#     'company': 'insightrix research inc.',
#     'time': '13 yrs 8 mos',
#     'description': 'insightrix research inc.insightrix research inc.',
#     'location': None},
#    {'position': 'university of chicago survey lab',
#     'company': 'university of chicago',
#     'time': '5 yrs',
#     'description': 'university of chicago survey labuniversity of chicago survey lab',
#     'location': None},
#    {'position': 'rock brigade',
#     'company': 'brigade brazil',
#     'time': '7 yrs 1 mo',
#     'description': '7 yrs 1 mojan 1986 - jan 1993',
#     'location': None}]},
#  'Joanna Doyle': {'education': [{'school': 'university of chicago',
#     'degree': "master's degree, anthropology",
#     'time': '1994 - 1998'},
#    {'school': 'northwestern university',
#     'degree': "master's degree, journalism",
#     'time': '1979 - 1980'},
#    {'school': None, 'degree': None, 'time': ''}],
#   'experience': [{'position': 'director',
#     'company': 'parent engagement institute at logan square neighborhood association',
#     'time': '8 yrs 5 mos',
#     'description': 'parent engagement institute at logan square neighborhood associationparent engagement institute at logan square neighborhood association',
#     'location': '2840 n. milwaukee ave., chicago, illinois'},
#    {'position': 'lead education organizer',
#     'company': 'logan square neighborhood association',
#     'time': '21 yrs 9 mos',
#     'description': "organize with neighborhood parents to influence schools and the school district in the best interests of the students.  this involves 8 elementary schools which collectively educate 6000+  students from mostly spanish-speaking and low-income families. lsna's foundational program is the parent mentor program which places parents mostly mothers) in classrooms as tutors, but i have also helped design and implement a variety of programs that build from parent mentors, as those parents move on to do home visits, americorps tutoring, and become teachers through grow your own teachers.organize with neighborhood parents to influence schools and the school district in the best interests of the students.  this involves 8 elementary schools which collectively educate 6000+  students from mostly spanish-speaking and low-income families.  \nlsna's foundational program is the parent mentor program which places parents mostly mothers) in classrooms as tutors, but i have also helped design and implement a variety of programs that build from parent mentors, as those parents move on to do home visits, americorps tutoring, and become teachers through grow your own teachers.",
#     'location': None}]},
#  'Amber Gibbs': {'education': [{'school': 'university of chicago',
#     'degree': 'master of arts, social science/psychology',
#     'time': None},
#    {'school': 'wittenberg university',
#     'degree': 'bachelor of arts, psychology',
#     'time': None},
#    {'school': 'wittenberg university',
#     'degree': "bachelor's degree, psychology",
#     'time': None}],
#   'experience': [{'position': 'cuyahoga county board of developmental disabilities',
#     'company': '15 yrs 1 mo',
#     'time': '3 yrs',
#     'description': 'plan, organize, and direct all functions of the community and medicaid services department, including support administration services, medicaid waiver enrollment and planning, associated business functions including budget management. responsible for department of 250 staff, experience with bargaining unit contracts and labor negotiations. plan, organize, and direct all functions of the community and medicaid services department, including support administration services, medicaid waiver enrollment and planning, associated business functions including budget management. responsible for department of 250 staff, experience with bargaining unit contracts and labor negotiations. ',
#     'location': None},
#    {'position': 'adjunct faculty',
#     'company': 'lorain county community college',
#     'time': '21 yrs 1 mo',
#     'description': 'lorain county community collegelorain county community college',
#     'location': None},
#    {'position': 'program advisor',
#     'company': 'bridgeway, inc.',
#     'time': '2 yrs',
#     'description': 'program advisorprogram advisor',
#     'location': None},
#    {'position': 'qmrp, quality assurance coordinator',
#     'company': 'welcome house, inc.',
#     'time': '5 yrs',
#     'description': 'qmrp, quality assurance coordinatorqmrp, quality assurance coordinator',
#     'location': None}]},
#  'Sarah Makela': {'education': [{'school': 'executive director',
#     'degree': 'growcommunity',
#     'time': None},
#    {'school': 'the university of chicago',
#     'degree': '12 yrs 9 mos',
#     'time': 'greater chicago area'},
#    {'school': 'university of chicago',
#     'degree': 'doctor of philosophy , sociology',
#     'time': '2002 - 2014'},
#    {'school': 'university of chicago',
#     'degree': "master's degree, social sciences",
#     'time': '2000 - 2001'},
#    {'school': 'university of michigan',
#     'degree': "bachelor's degree, english",
#     'time': '1992 - 1995'}],
#   'experience': [{'position': 'research assistant',
#     'company': 'consortium on chicago school research',
#     'time': '2 yrs',
#     'description': 'consortium on chicago school researchconsortium on chicago school research',
#     'location': 'greater chicago area'},
#    {'position': 'research assistant, chicago annenberg research project',
#     'company': 'consortium on chicago school research',
#     'time': '1 yr 1 mo',
#     'description': 'research assistant, chicago annenberg research projectresearch assistant, chicago annenberg research project',
#     'location': 'greater chicago area'}]},
#  'Keith Mataya': {'education': [{'school': 'instructor',
#     'degree': 'aspen learning',
#     'time': None},
#    {'school': 'university of chicago',
#     'degree': 'master of arts , social sciences',
#     'time': None},
#    {'school': 'georgetown university',
#     'degree': 'bachelor of arts - ba, political science and government',
#     'time': None}],
#   'experience': [{'position': None,
#     'company': None,
#     'time': 'keith mataya commented on a post • 2mo2mo',
#     'description': '\n\n \n \nwell deserved! i look forward to seeing how you expand support for youth and families!',
#     'location': None},
#    {'position': 'big brothers big sisters of orange county & the inland empire',
#     'company': None,
#     'time': '\n\nvp of grants and researchvp of grants and research\n\n \n \njul 2021 - present',
#     'description': 'i manage a grants portfolio spanning three counties that promotes educational success, career exploration, and healthy lives. my work encompasses developing relationships with government, schools, corporations, foundations, and fellow nonprofits to provide more youth with positive adult role models.i manage a grants portfolio spanning three counties that promotes educational success, career exploration, and healthy lives. my work encompasses developing relationships with government, schools, corporations, foundations, and fellow nonprofits to provide more youth with positive adult role models.',
#     'location': None},
#    {'position': 'grants manager',
#     'company': 'big brothers big sisters of greater los angeles',
#     'time': '1 yr 4 mos',
#     'description': "i developed proposals and directly solicited grants from corporate foundations, private foundations and government entities to support bbbsla's general operations, programs, and special projects.i work with the program team to engage funders, understand programmatic goals, and evaluate outcomes. i also collaborate with finance on the collection and analysis of budget information for cost applications for grant reports and other materials.i developed proposals and directly solicited grants from corporate foundations, private foundations and government entities to support bbbsla's general operations, programs, and special projects.\n\ni work with the program team to engage funders, understand programmatic goals, and evaluate outcomes. i also collaborate with finance on the collection and analysis of budget information for cost applications for grant reports and other materials. ",
#     'location': None},
#    {'position': 'program director',
#     'company': 'constitutional rights foundation',
#     'time': '2 yrs 2 mos',
#     'description': 'i wrote grants, analyzed data, and collaborated on project partnerships in support of educational programs. projects included work with the epa, gates foundation, max factor foundation, and library of congress.i also managed civic engagement and college prep projects for students in la.i wrote grants, analyzed data, and collaborated on project partnerships in support of educational programs. projects included work with the epa, gates foundation, max factor foundation, and library of congress.\n\ni also managed civic engagement and college prep projects for students in la. ',
#     'location': None},
#    {'position': 'community director',
#     'company': "steve & kate's",
#     'time': '2 yrs 2 mos',
#     'description': "i was part of the team that expanded steve and kate's camp from the bay area into la. i established new programs in santa monica and mar vista and hired and trained staff across the region. i also helped design new program elements for skc sites across the country, including innovative outdoor play components.i was part of the team that expanded steve and kate's camp from the bay area into la. i established new programs in santa monica and mar vista and hired and trained staff across the region. i also helped design new program elements for skc sites across the country, including innovative outdoor play components.",
#     'location': None}]},
#  'Megan McCormick': {'education': [], 'experience': []},
#  'Nayantara Mehta': {'education': [{'school': 'university of chicago',
#     'degree': 'ma, social sciences',
#     'time': '2000 - 2001'}],
#   'experience': [{'position': 'national employment law project',
#     'company': '7 yrs 9 mos',
#     'time': '5 yrs 2 mosdec 2017 - present',
#     'description': 'for more than 45 years, nelp has sought to ensure that america upholds for all workers the promise of opportunity and economic security through work.nelp fights for policies to create good jobs, expand access to work, and strengthen protections and support for low-wage workers and the unemployed.we publish research that illuminates workers’ issues; promote policies that improve workers’ lives; lend deep legal and policy expertise to important cases and campaigns; and partner with allies to advance crucial reforms.for more than 45 years, nelp has sought to ensure that america upholds for all workers the promise of opportunity and economic security through work.\n\nnelp fights for policies to create good jobs, expand access to work, and strengthen protections and support for low-wage workers and the unemployed.\n\nwe publish research that illuminates workers’ issues; promote policies that improve workers’ lives; lend deep legal and policy expertise to important cases and campaigns; and partner with allies to advance crucial reforms.',
#     'location': None},
#    {'position': 'chair board of directors',
#     'company': 'asian pacific environmental network ',
#     'time': '6 yrs 1 mo',
#     'description': 'apen brings together a collective voice to develop an alternative agenda for environmental, social and economic justice. through building an organized movement, apen strives to bring fundamental changes to economic and social institutions that will prioritize public good over profits and promote the right of every person to a decent, safe, affordable quality of life, and the right to participate in decisions affecting our lives. apen holds this vision of environmental justice for all people.apen brings together a collective voice to develop an alternative agenda for environmental, social and economic justice. through building an organized movement, apen strives to bring fundamental changes to economic and social institutions that will prioritize public good over profits and promote the right of every person to a decent, safe, affordable quality of life, and the right to participate in decisions affecting our lives. apen holds this vision of environmental justice for all people.',
#     'location': None},
#    {'position': 'executive board member',
#     'company': 'american constitution society',
#     'time': '11 yrs 5 mos',
#     'description': 'the american constitution society  believes that law should be a force to improve the lives of all people. acs works for positive change by shaping debate on vitally important legal and constitutional issues through development and promotion of high-impact ideas to opinion leaders and the media; by building networks of lawyers, law students, judges and policymakers dedicated to those ideas; and by countering the activist conservative legal movement that has sought to erode our enduring constitutional values.the american constitution society  believes that law should be a force to improve the lives of all people. acs works for positive change by shaping debate on vitally important legal and constitutional issues through development and promotion of high-impact ideas to opinion leaders and the media; by building networks of lawyers, law students, judges and policymakers dedicated to those ideas; and by countering the activist conservative legal movement that has sought to erode our enduring constitutional values.',
#     'location': None},
#    {'position': 'alliance for justice',
#     'company': '8 yrs 9 mos',
#     'time': '5 yrs 1 mo',
#     'description': 'bolder advocacy promotes active engagement in democratic processes and institutions by giving nonprofits and foundations the confidence to advocate effectively and by protecting their right to do so. our goal is to demystify and decode advocacy by equipping organizations with knowledge and tools. we help organizations fully understand the rules and become assertive in their right to pursue their policy goals.bolder advocacy is an initiative of the alliance for justice – a national association of more than 100 organizations that are united by a commitment to a fair, just, and free america where everyone has equal access to justice and can fully participate in our democracy.bolder advocacy promotes active engagement in democratic processes and institutions by giving nonprofits and foundations the confidence to advocate effectively and by protecting their right to do so. our goal is to demystify and decode advocacy by equipping organizations with knowledge and tools. we help organizations fully understand the rules and become assertive in their right to pursue their policy goals.\n\nbolder advocacy is an initiative of the alliance for justice – a national association of more than 100 organizations that are united by a commitment to a fair, just, and free america where everyone has equal access to justice and can fully participate in our democracy.',
#     'location': None},
#    {'position': "women's policy institute ",
#     'company': '2 yrs',
#     'time': '11 mos',
#     'description': "more effective than a single lobby group, the women’s policy institute amplifies the voices of women who are leading grassroots social justice work, training them on how legislation is made and connecting them to those in power.through the women's policy institute, a yearlong program of training retreats in sacramento, we teach women activists and grassroots organizations how to successfully navigate the labyrinth of sacramento.more effective than a single lobby group, the women’s policy institute amplifies the voices of women who are leading grassroots social justice work, training them on how legislation is made and connecting them to those in power.\n\nthrough the women's policy institute, a yearlong program of training retreats in sacramento, we teach women activists and grassroots organizations how to successfully navigate the labyrinth of sacramento.",
#     'location': "more effective than a single lobby group, the women’s policy institute amplifies the voices of women who are leading grassroots social justice work, training them on how legislation is made and connecting them to those in power.\n\nthrough the women's policy institute, a yearlong program of training retreats in sacramento, we teach women activists and grassroots organizations how to successfully navigate the labyrinth of sacramento."},
#    {'position': 'william & mary',
#     'company': 'ba, religion',
#     'time': 'endorsed by melissa mikesell and 1 other who is highly skilled at thisendorsed by melissa mikesell and 1 other who is highly skilled at this',
#     'description': 'endorsed by melissa mikesell and 1 other who is highly skilled at thisendorsed by melissa mikesell and 1 other who is highly skilled at this',
#     'location': None}]},
#  'Kate Miller': {'education': [{'school': 'university of chicago',
#     'degree': 'masters, social science',
#     'time': '2000 - 2001'}],
#   'experience': [{'position': 'you both studied at university of chicago',
#     'company': 'kate started at university of chicago before you started',
#     'time': '\n\n \n \ncongratulations!',
#     'description': '\n\n \n \nthanks, gregory, for your thoughts. it made my day to read and listen to appreciation and warmth in this community',
#     'location': None},
#    {'position': 'legal council for health justice',
#     'company': '21 yrs 1 mo',
#     'time': 'jun 2018 - present',
#     'description': 'assists hiv+ individuals with legal problems related to immigration, public benefits, estate planning, discrimination in employment, medical care and other services, confidentiality and privacy of health information and returning to work. accredited representative with the board of immigration appeal and qualifed non-attorney representative with the social security administration. project director of the in-person counselor program at alcc, educating and enrolling people in health insurance through the affordable care act.assists hiv+ individuals with legal problems related to immigration, public benefits, estate planning, discrimination in employment, medical care and other services, confidentiality and privacy of health information and returning to work. accredited representative with the board of immigration appeal and qualifed non-attorney representative with the social security administration. project director of the in-person counselor program at alcc, educating and enrolling people in health insurance through the affordable care act.',
#     'location': None},
#    {'position': None,
#     'company': 'website',
#     'time': '21 yrs 1 mo',
#     'description': 'outreach to homeless, mentally ill individuals assessment of disability casesconnecting individuals to carerepresenting eligible individuals to obtain benefitstracking of data for quarterly reportswriting quarterly reportsoutreach to homeless, mentally ill individuals \nassessment of disability cases\nconnecting individuals to care\nrepresenting eligible individuals to obtain benefits\ntracking of data for quarterly reports\nwriting quarterly reports',
#     'location': None},
#    {'position': 'community advisory board',
#     'company': 'project wish',
#     'time': '5 yrs 10 mos',
#     'description': "serve as community advisory board member for project wish. co-chair of the global community advisory board of the hiv vaccine trials network. co-chair of the women's hiv research collaborative, a committee of the legacy project.serve as community advisory board member for project wish. co-chair of the global community advisory board of the hiv vaccine trials network. co-chair of the women's hiv research collaborative, a committee of the legacy project.",
#     'location': None},
#    {'position': 'volunteer coordinator',
#     'company': '61st street farmers market',
#     'time': '5 yrs 5 mos',
#     'description': 'coordinated volunteers to staff the 61st street farmers market and assist with ebt/snap program at the market. board member at experimental stationcoordinated volunteers to staff the 61st street farmers market and assist with ebt/snap program at the market. board member at experimental station',
#     'location': None},
#    {'position': 'co chair',
#     'company': 'womens hiv research collaborative',
#     'time': '2 yrs 1 mo',
#     'description': 'the hanc legacy women’s hiv research collaborative  provides culturally appropriate guidance and leadership in development, implementation and dissemination of information about hiv research focused on and responsive to the needs of women and girls living in the united states.the hanc legacy women’s hiv research collaborative  provides culturally appropriate guidance and leadership in development, implementation and dissemination of information about hiv research focused on and responsive to the needs of women and girls living in the united states.',
#     'location': None}]},
#  'Matthew Nelson': {'education': [{'school': 'fisher investments',
#     'degree': '7 yrs 7 mos',
#     'time': None},
#    {'school': 'the university of chicago booth school of business',
#     'degree': 'master of business administration , econometrics & statistics, strategic management, operations, general management, entrepreneurship',
#     'time': '2011 - 2013'}],
#   'experience': [{'position': 'habitat for humanity east bay/silicon valley',
#     'company': None,
#     'time': '\n\ncdfi directorcdfi director\n\n \n \nnov 2020 - present',
#     'description': "manage all operations for habitat for humanity east bay/silicon valley's community development financial institution .  market and execute both financing and lending transactions with affordable housing organizations serving the low-income community.manage all operations for habitat for humanity east bay/silicon valley's community development financial institution .  market and execute both financing and lending transactions with affordable housing organizations serving the low-income community.",
#     'location': 'started and grew cdfi. drove high-impact operational efficiency improvements and led expansion efforts for both the habitat for humanity restores and within the habitat ebsv finance department.'},
#    {'position': 'northwestern university',
#     'company': 'ba, economics, mathematics and leadership',
# ...
#  'Grant Stanton': {'education': [], 'experience': []},
#  'Jonathan Camacho': {'education': [{'school': 'university of chicago',
#     'degree': 'doctor of philosophy , sociology',
#     'time': '2014 - 2019'},
#    {'school': 'university of chicago',
#     'degree': 'master of arts , sociology',
#     'time': '2016'},
#    {'school': 'new york university',
#     'degree': 'bachelor of arts , sociology',
#     'time': '2012'}],
#   'experience': [{'position': 'quantitative user experience  researcher',
#     'company': None,
#     'time': 'jul 2022 - present',
#     'description': '⋄ influenced product roadmap and strategy by identifying key user pain points, behavioral patterns, and metrics through the synthesis of user feedback, heuristics, log data, and tracking surveys.⋄ created user journeys, narratives, and dashboards for key stakeholders by leveraging python, r, and sql to perform large scale analytics of user feedback, logs, and survey data.⋄ led quantitative ux insights for a foundational pillar in google cloud to drive key product impact.⋄ spearheaded and acted as ic lead on multiple pillar and org initiatives to improve user sentiment mea- surement, including new systems to automate and improve the efficiency of research systems.⋄ influenced product roadmap and strategy by identifying key user pain points, behavioral patterns, and metrics through the synthesis of user feedback, heuristics, log data, and tracking surveys.\n⋄ created user journeys, narratives, and dashboards for key stakeholders by leveraging python, r, and sql to perform large scale analytics of user feedback, logs, and survey data.\n⋄ led quantitative ux insights for a foundational pillar in google cloud to drive key product impact.\n⋄ spearheaded and acted as ic lead on multiple pillar and org initiatives to improve user sentiment mea- surement, including new systems to automate and improve the efficiency of research systems.',
#     'location': None},
#    {'position': 'user experience researcher',
#     'company': None,
#     'time': 'jul 2020 - jul 2022',
#     'description': '⋄ led an org-level jtbd analysis, guiding product teams in applying the results to their roadmaps.⋄ ic lead on a cross-org strategic initiative, ic lead for research org project, regularly supported ux insights for 8 xfn teams, and mentored other uxrs in their research analyses.⋄ identified customer segmentation, barriers to adoption, user pain points, and mental models through surveys, interviews, and usability studies to influence product roadmaps across pillars/xfn teams.⋄ led stratified, randomized, international surveys/log data analysis using sql, r, and python, including post-stratification weighting, visualization, and ml/statistical modeling.⋄ led an org-level jtbd analysis, guiding product teams in applying the results to their roadmaps.\n⋄ ic lead on a cross-org strategic initiative, ic lead for research org project, regularly supported ux insights for 8 xfn teams, and mentored other uxrs in their research analyses.\n⋄ identified customer segmentation, barriers to adoption, user pain points, and mental models through surveys, interviews, and usability studies to influence product roadmaps across pillars/xfn teams.\n⋄ led stratified, randomized, international surveys/log data analysis using sql, r, and python, including post-stratification weighting, visualization, and ml/statistical modeling.',
#     'location': None},
#    {'position': 'user experience  research intern ',
#     'company': 'facebook',
#     'time': '3 mos',
#     'description': '⋄ developed and executed both ux interviews and surveys to leverage insights for product stakeholders.⋄ produced statistical models in r and stata, delivering actionable, competitive insights to my team.⋄ developed and executed both ux interviews and surveys to leverage insights for product stakeholders.\n⋄ produced statistical models in r and stata, delivering actionable, competitive insights to my team.',
#     'location': None},
#    {'position': 'quantitative ux research intern ',
#     'company': 'facebook',
#     'time': '4 mos',
#     'description': 'conducting survey research on facebook users and non-users and analyzing this data using statistical modeling and descriptive statistics  to determine opportunities that can be leveraged to drive product growth.running sql queries on facebook log data using python, presto, and hive and building analytic models that provide research insights and inform product recommendations for strategic markets.conducting survey research on facebook users and non-users and analyzing this data using statistical modeling and descriptive statistics  to determine opportunities that can be leveraged to drive product growth.\n\nrunning sql queries on facebook log data using python, presto, and hive and building analytic models that provide research insights and inform product recommendations for strategic markets.',
#     'location': None},
#    {'position': 'graduate research assistant',
#     'company': 'university of chicago',
#     'time': '2 yrs 6 mos',
#     'description': 'r.a. work for kathleen cagney, dept. of sociologyongoing research for a project analyzing energy use in chicago. performed research on a project assessing the effect of neighborhood crime on health using the dallas heart study.r.a. work for jenny trinitapoli, dept. of sociologydata cleaning and research on the tsogolo la thanzi  project including supervision and instruction for two undergraduate research assistants on the project. tsogolo la thanzi  is a longitudinal study in balaka, malawi designed by jenny trinitapoli and sara yeatman to examine how young people navigate reproduction in an aids epidemic. r.a. work for kathleen cagney, dept. of sociology\nongoing research for a project analyzing energy use in chicago. performed research on a project assessing the effect of neighborhood crime on health using the dallas heart study.\n\nr.a. work for jenny trinitapoli, dept. of sociology\ndata cleaning and research on the tsogolo la thanzi  project including supervision and instruction for two undergraduate research assistants on the project. tsogolo la thanzi  is a longitudinal study in balaka, malawi designed by jenny trinitapoli and sara yeatman to examine how young people navigate reproduction in an aids epidemic. ',
#     'location': None}]},
#  'Ke Wang': {'education': [{'school': 'harvard kennedy school',
#     'degree': 'doctor of philosophy - phd, public policy',
#     'time': '2019 - 2024'},
#    {'school': 'university of chicago',
#     'degree': "master's degree, psychology",
#     'time': '2016 - 2017'},
#    {'school': 'wuhan university',
#     'degree': 'bachelor of science , psychology',
#     'time': '2012 - 2016'}],
#   'experience': [{'position': 'research fellow',
#     'company': 'harvard university',
#     'time': '2 yrs 1 mo',
#     'description': 'harvard universityharvard university',
#     'location': None},
#    {'position': 'research assistant',
#     'company': 'chinese academy of sciences',
#     'time': '3 mos',
#     'description': 'assisted with research projects on culture at social and personality psychology labanalyzed data with rsupervisor: dr. huajian caiassisted with research projects on culture at social and personality psychology lab\nanalyzed data with r\nsupervisor: dr. huajian cai',
#     'location': None},
#    {'position': 'csst summer research program',
#     'company': 'ucla',
#     'time': '3 mos',
#     'description': 'independent research project at learning & forgetting labdesigned and built experiments with collector analyzed data with excel and spsssupervisor: dr. elizabeth bjork and dr. veronica yanindependent research project at learning & forgetting lab\ndesigned and built experiments with collector \nanalyzed data with excel and spss\nsupervisor: dr. elizabeth bjork and dr. veronica yan',
#     'location': None},
#    {'position': 'research assistant',
#     'company': 'chinese academy of sciences',
#     'time': '3 mos',
#     'description': 'assisted with research projects on culture and open data at social and personality psychology labsupervisor: dr. huajian caiassisted with research projects on culture and open data at social and personality psychology lab\nsupervisor: dr. huajian cai',
#     'location': None}]},
#  'Tiara Starks': {'education': [{'school': 'university of kentucky college of medicine',
#     'degree': 'doctor of philosophy - phd, neuroscience',
#     'time': '202018 - 2020'},
#    {'school': 'university of chicago',
#     'degree': 'master of arts - ma, social science - psychology',
#     'time': '2016 - 2017'},
#    {'school': 'northwestern university',
#     'degree': 'bachelor of arts - ba, cognitive science - cognitive neuroscience',
#     'time': '2010 - 2014'}],
#   'experience': [{'position': 'project coordinator',
#     'company': None,
#     'time': 'sep 2021 - present',
#     'description': '\nsociety for black brain and behavioral scientists logo',
#     'location': None},
#    {'position': 'graduate research assistant',
#     'company': 'university of kentucky college of medicine',
#     'time': '2 yrs 6 mos',
#     'description': 'university of kentucky college of medicineuniversity of kentucky college of medicine',
#     'location': None},
#    {'position': 'lab manager/research scientist ii',
#     'company': 'university of chicago',
#     'time': '1 yr 10 mos',
#     'description': 'lab manager/research scientist iilab manager/research scientist ii',
#     'location': 'greater chicago area'},
#    {'position': 'research assistant',
#     'company': 'northwestern university',
#     'time': '2 yrs 3 mos',
#     'description': 'northwestern universitynorthwestern university',
#     'location': 'evanston, il'}]},
#  'Rivka Baker Keusch': {'education': [{'school': 'university of chicago',
#     'degree': 'master of arts , middle eastern studies',
#     'time': '2016 - jun 2018'},
#    {'school': 'university of chicago',
#     'degree': 'bachelor’s degree with departmental and college honors, near eastern languages and civilizations',
#     'time': '2013 - 2017'},
#    {'school': 'bernie victory captain coach',
#     'degree': 'bernie sanders for president',
#     'time': None}],
#   'experience': [{'position': 'organizing committee member',
#     'company': 'new york state legislative workers union',
#     'time': '6 mos',
#     'description': 'developed 1:1 script for union organizers to use during weekly phonebanks.organized colleagues across nys senate offices in support of the nys senate union through 1:1s, happy hours, and know your rights sessions.developed 1:1 script for union organizers to use during weekly phonebanks.\norganized colleagues across nys senate offices in support of the nys senate union through 1:1s, happy hours, and know your rights sessions.',
#     'location': None},
#    {'position': 'director of operations',
#     'company': 'new york state senator jessica ramos',
#     'time': '7 mos',
#     'description': '•\tdeveloped tracking and reporting procedures to improve district office operations.•\tcoordinated donation drives, resulting in 7,500 backpacks and 700 turkeys donated to in-district families.•\tplanned and executed annual health & wellness fair in partnership with 28 local organizations.•\tresearched legislative ideas for expanding mwbe programs to include trans people and disabled people, creating a trans civil workforce development program modeled after la programs, regulating the accessibility of ride share programs, and instituting a state task force on issues faced by tgncbi people in custody.•\toversaw cannabis, disability justice, and trans and queer justice legislation and related events.•\tdeveloped tracking and reporting procedures to improve district office operations.\n•\tcoordinated donation drives, resulting in 7,500 backpacks and 700 turkeys donated to in-district families.\n•\tplanned and executed annual health & wellness fair in partnership with 28 local organizations.\n•\tresearched legislative ideas for expanding mwbe programs to include trans people and disabled people, creating a trans civil workforce development program modeled after la programs, regulating the accessibility of ride share programs, and instituting a state task force on issues faced by tgncbi people in custody.\n•\toversaw cannabis, disability justice, and trans and queer justice legislation and related events.',
#     'location': None},
#    {'position': 'campaign manager',
#     'company': 'jessica ramos for state senate',
#     'time': '1 yr',
#     'description': '•\toutperformed democratic gubernatorial ticket in district 13, receiving over 3000 more votes and 4.3% points.•\tran a cross-campaign petitioning operation of 200 volunteers for eight other queens-based candidates.•\tsecured over 20 endorsements from unions, democratic clubs, and progressive organizations.•\tmanaged senior staff, consultants, and vendors and oversaw finance, digital, and mail plan.•\tmanaged campaign budget of 400k.•\tdesigned campaign lit, mail, digital graphics, and campaign-branded materials.•\toutperformed democratic gubernatorial ticket in district 13, receiving over 3000 more votes and 4.3% points.\n•\tran a cross-campaign petitioning operation of 200 volunteers for eight other queens-based candidates.\n•\tsecured over 20 endorsements from unions, democratic clubs, and progressive organizations.\n•\tmanaged senior staff, consultants, and vendors and oversaw finance, digital, and mail plan.\n•\tmanaged campaign budget of 400k.\n•\tdesigned campaign lit, mail, digital graphics, and campaign-branded materials.',
#     'location': None},
#    {'position': 'movement relaunch consultant',
#     'company': 'ifnotnow',
#     'time': '1 yr 9 mos',
#     'description': 'co-owned overall training, content, & facilitation for twice monthly retreats.worked with three others to coordinate group of ten leaders to evaluate how the landscape  has shifted since ifnotnow was founded, and how the current ecology might impact the overall strategic objective, strategy, and goals of the movement moving forward.co-owned overall training, content, & facilitation for twice monthly retreats.\n\nworked with three others to coordinate group of ten leaders to evaluate how the landscape  has shifted since ifnotnow was founded, and how the current ecology might impact the overall strategic objective, strategy, and goals of the movement moving forward.',
#     'location': None},
#    {'position': 'test & trace corps queens borough outreach director',
#     'company': None,
#     'time': 'sep 2021 - nov 2021',
#     'description': 'the nyc test & trace corps announced today that organizations participating in the ‘nyc vaccine referral bonus’ program, an initiative launched two months ago to encourage more new yorkers to get the covid-19 vaccine, have now facilitated over 20,000 vaccinations. the city has worked with community-based organizations to encourage their members to get vaccinated, awarding them $100 for each referral that leads to an individual receiving their first dose of the covid-19 vaccine at a city-run site.the nyc test & trace corps announced today that organizations participating in the ‘nyc vaccine referral bonus’ program, an initiative launched two months ago to encourage more new yorkers to get the covid-19 vaccine, have now facilitated over 20,000 vaccinations. the city has worked with community-based organizations to encourage their members to get vaccinated, awarding them $100 for each referral that leads to an individual receiving their first dose of the covid-19 vaccine at a city-run site.',
#     'location': None},
#    {'position': 'the hebrew university of jerusalem',
#     'company': 'special programs--herman e. and lotte schaalman civilization program in jerusalem, near and middle eastern studies',
#     'time': 'jewish studiesskills: israeli-palestinian conflict',
#     'description': 'special programs--herman e. and lotte schaalman civilization program in jerusalem, near and middle eastern studiesspecial programs--herman e. and lotte schaalman civilization program in jerusalem, near and middle eastern studies',
#     'location': None}]}}

# %%
len(data)
# Out:
# 640

# %%
import csv
with open('cleaned_data_initial.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    for key, value in data.items():
        for category, sections in value.items():
            for section in sections:
                writer.writerow([key, section])

# %%
df = pd.read_csv('cleaned_data_initial.csv', header = None)

# %%
import csv
with open('cleaned_data.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    writer.writerow(['name', 'experience_type', 'school', 'degree', 'time', 'position', 'company', 'description', 'location'])
    for index, row in df.iterrows():
        name = row[0]
        details = row[1]
        school = ''
        degree = ''
        time = ''
        position = ''
        company = ''
        description = ''
        location = ''
        experience_type = 'work'
        try:
            school = ast.literal_eval(details)['school']
            experience_type = 'school'
        except:
            pass
        try:
            degree = ast.literal_eval(details)['degree']
        except:
            pass
        try:
            time = ast.literal_eval(details)['time']
        except:
            pass
        try:
            position = ast.literal_eval(details)['position']
        except:
            pass 
        try:
            company = ast.literal_eval(details)['company']
        except:
            pass
        try:
            description = ast.literal_eval(details)['description']
        except:
            pass
        try:
            location = ast.literal_eval(details)['location']
        except:
            pass
        writer.writerow([name, experience_type, school, degree, time, position, company, description, location])
