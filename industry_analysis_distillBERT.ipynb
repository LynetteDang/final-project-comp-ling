# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 44.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 82.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 11.9 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

tokenizer = AutoTokenizer.from_pretrained("sampathkethineedi/industry-classification")  
model = AutoModelForSequenceClassification.from_pretrained("sampathkethineedi/industry-classification")

industry_tags = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
industry_tags("bain & company")
# Out:
# ...
# [{'label': 'Investment Banking & Brokerage', 'score': 0.8233681321144104}]

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

tokenizer = AutoTokenizer.from_pretrained("sampathkethineedi/industry-classification")  
model = AutoModelForSequenceClassification.from_pretrained("sampathkethineedi/industry-classification")

industry_tags = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
industry_tags("lead day-to-day business operations for research-based communications firm, including client service, hr, business development, business strategy, finance, innovation and marketinglead the design and execution of message and strategy development projects for clients in advocacy, philanthropy, government and business—including rockefeller foundation, packard foundation and ford foundationserve as counsel to clients on research, branding, message development, advertising, policy outreach, grassroots mobilization and digital planning and executionhave helped build the team from 4 people to 20+ with systems and processes that foster a productive, collaborative and high-quality working environmentlead day-to-day business operations for research-based communications firm, including client service, hr, business development, business strategy, finance, innovation and marketing\n\nlead the design and execution of message and strategy development projects for clients in advocacy, philanthropy, government and business—including rockefeller foundation, packard foundation and ford foundation\n\nserve as counsel to clients on research, branding, message development, advertising, policy outreach, grassroots mobilization and digital planning and execution\n\nhave helped build the team from 4 people to 20+ with systems and processes that foster a productive, collaborative and high-quality working environment")
# Out:
# [{'label': 'Research & Consulting Services', 'score': 0.9964021444320679}]

# %%
pip install nlu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 KB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.6/532.6 KB 16.8 MB/s eta 0:00:00
# ...

# %%
pip install pyspark==3.0.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.8/204.8 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 KB 18.5 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.0.2-py2.py3-none-any.whl size=205186690 sha256=d942de324ae3363fa5647b99369d8a5975843324e10977a14593d22880695768
#   Stored in directory: /root/.cache/pip/wheels/79/f9/b5/deac3c0c2cb1b00cea51109823d12fc5f2fe05b0f63d4342ff
# Successfully built pyspark
# ...

# %%
import nlu
nlu_model = nlu.load("en.classify.distilbert_sequence.industry")
# Out:
# distilbert_sequence_classifier_industry download started this may take some time.
# Approximate size to download 238.4 MB
# [OK!]

# %%
nlu_model.predict("""lead day-to-day business operations for research-based communications firm, including client service, hr, business development, business strategy, finance, innovation and marketinglead the design and execution of message and strategy development projects for clients in advocacy, philanthropy, government and business—including rockefeller foundation, packard foundation and ford foundationserve as counsel to clients on research, branding, message development, advertising, policy outreach, grassroots mobilization and digital planning and executionhave helped build the team from 4 people to 20+ with systems and processes that foster a productive, collaborative and high-quality working environmentlead day-to-day business operations for research-based communications firm, including client service, hr, business development, business strategy, finance, innovation and marketing\n\nlead the design and execution of message and strategy development projects for clients in advocacy, philanthropy, government and business—including rockefeller foundation, packard foundation and ford foundation\n\nserve as counsel to clients on research, branding, message development, advertising, policy outreach, grassroots mobilization and digital planning and execution\n\nhave helped build the team from 4 people to 20+ with systems and processes that foster a productive, collaborative and high-quality working environment""")
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#   classified_sequence classified_sequence_confidence  \
# 0         Advertising                       0.995992
#
#                                             sentence
# 0  lead day-to-day business operations for resear...

# %%
nlu_model.predict("""helped lead and then served as a senior consultant for national consulting firm specializing in           development and small business finance strategies in under-invested communities throughout the us, as well as business strategy, evaluation, and capital raising for international microfinance institutions. past clients included the ford foundation, the aspen institute, usaid, oecd, financial institutions, and local governments.helped lead and then served as a senior consultant for national consulting firm specializing in           development and small business finance strategies in under-invested communities throughout the us, as well as business strategy, evaluation, and capital raising for international microfinance institutions. past clients included the ford foundation, the aspen institute, usaid, oecd, financial institutions, and local governments""")
# Out:
#               classified_sequence classified_sequence_confidence  \
# 0  Research & Consulting Services                       0.999602
# 0  Research & Consulting Services                        0.51793
# 0  Research & Consulting Services                       0.999602
# 0  Research & Consulting Services                       0.619559
#
#                                             sentence
# 0  helped lead and then served as a senior consul...
# 0  past clients included the ford foundation, the...
# 0  helped lead and then served as a senior consul...
# 0   past clients included the ford foundation, th...

# %%
nlu_model.predict("""independent consultant, impactcommons""")['classified_sequence'][0]
# Out:
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
# 'Research & Consulting Services'

# %%
import pandas as pd

work = pd.read_csv('work_exp_with_label.csv')

# %%
industry = []

# %%
len(work['description'].dropna())
# Out:
# 2738

# %%
work = work.dropna(subset = ['description'])
industry_true = work[['industry']]

# %%
len(industry_true)
# Out:
# 2738

# %%
for i, row in enumerate(work['description'].dropna()):
  if type(row) == str:
    if type(nlu_model.predict(row)['classified_sequence'][0]) == str:
      ind_pred = nlu_model.predict(row)['classified_sequence'][0]
      industry.append(ind_pred)
    else:
      industry.append('Others')

# %%
len(industry)
# Out:
# 2738

# %%
industry
# Out:
# []

# %%
industry_true
# Out:
#                            industry
# 0                            Others
# 1                               Law
# 2     Policy/Government/Social Work
# 3                            Others
# 4                Education/Research
# ...                             ...
# 2782               Business/Finance
# 2783           Charity/Volunteering
# 2784                         Others
# 2785           Charity/Volunteering
# 2786                         Others
#
# [2738 rows x 1 columns]

# %%
id2label = {'0': 'Advertising',
 '1': 'Aerospace & Defense',
 '2': 'Apparel Retail',
 '3': 'Apparel, Accessories & Luxury Goods',
 '4': 'Application Software',
 '5': 'Asset Management & Custody Banks',
 '6': 'Auto Parts & Equipment',
 '7': 'Biotechnology',
 '8': 'Building Products',
 '9': 'Casinos & Gaming',
 '10': 'Commodity Chemicals',
 '11': 'Communications Equipment',
 '12': 'Construction & Engineering',
 '13': 'Construction Machinery & Heavy Trucks',
 '14': 'Consumer Finance',
 '15': 'Data Processing & Outsourced Services',
 '16': 'Diversified Metals & Mining',
 '17': 'Diversified Support Services',
 '18': 'Electric Utilities',
 '19': 'Electrical Components & Equipment',
 '20': 'Electronic Equipment & Instruments',
 '21': 'Environmental & Facilities Services',
 '22': 'Gold',
 '23': 'Health Care Equipment',
 '24': 'Health Care Facilities',
 '25': 'Health Care Services',
 '26': 'Health Care Supplies',
 '27': 'Health Care Technology',
 '28': 'Homebuilding',
 '29': 'Hotels, Resorts & Cruise Lines',
 '30': 'Human Resource & Employment Services',
 '31': 'IT Consulting & Other Services',
 '32': 'Industrial Machinery',
 '33': 'Integrated Telecommunication Services',
 '34': 'Interactive Media & Services',
 '35': 'Internet & Direct Marketing Retail',
 '36': 'Internet Services & Infrastructure',
 '37': 'Investment Banking & Brokerage',
 '38': 'Leisure Products',
 '39': 'Life Sciences Tools & Services',
 '40': 'Movies & Entertainment',
 '41': 'Oil & Gas Equipment & Services',
 '42': 'Oil & Gas Exploration & Production',
 '43': 'Oil & Gas Refining & Marketing',
 '44': 'Oil & Gas Storage & Transportation',
 '45': 'Packaged Foods & Meats',
 '46': 'Personal Products',
 '47': 'Pharmaceuticals',
 '48': 'Property & Casualty Insurance',
 '49': 'Real Estate Operating Companies',
 '50': 'Regional Banks',
 '51': 'Research & Consulting Services',
 '52': 'Restaurants',
 '53': 'Semiconductors',
 '54': 'Specialty Chemicals',
 '55': 'Specialty Stores',
 '56': 'Steel',
 '57': 'Systems Software',
 '58': 'Technology Distributors',
 '59': 'Technology Hardware, Storage & Peripherals',
 '60': 'Thrifts & Mortgage Finance',
 '61': 'Trading Companies & Distributors'}

# %%
industry_old = industry

# %%
for i, ind in enumerate(industry):
    if id2label['4']  in ind or id2label['15']  in ind or id2label['18']  in ind or id2label['19']  in ind or id2label['20']  in ind or id2label['57']  in ind or id2label['58']  in ind or id2label['59']  in ind or id2label['33'] in ind:
        industry[i] = 'Technology'
    elif id2label['30'] in ind:
        industry[i] = 'Human Resources'
    elif id2label['0']  in ind or id2label['2']  in ind or id2label['3']  in ind or id2label['5']  in ind or id2label['8']  in ind or id2label['9']  in ind or id2label['14']  in ind or id2label['29']  in ind or id2label['34']  in ind or id2label['35']  in ind or id2label['36']  in ind or id2label['37']  in ind or id2label['38']  in ind or id2label['40']  in ind or id2label['46']  in ind or id2label['49']  in ind or id2label['50']  in ind or id2label['52']  in ind or id2label['55']  in ind or id2label['60']  in ind or id2label['61'] in ind:
        industry[i] = 'Business/Finance'
    elif id2label['7']  in ind or id2label['23']  in ind or id2label['24']  in ind or id2label['25']  in ind or id2label['26']  in ind or id2label['27']  in ind or id2label['39']  in ind or id2label['47'] in ind:
        industry[i] = 'Healthcare'
    elif id2label['51'] in ind:
        industry[i] = 'Education/Research'
    elif id2label['31'] in ind:
        industry[i] = 'Consulting'
    elif id2label['14']  in ind or id2label['48'] in ind:
        industry[i] = 'Education/Research'
    elif id2label['17'] in ind:
        industry[i] = 'Charity/Volunteering'
    elif id2label['1']  in ind or id2label['21']  in ind or id2label['32'] in ind:
        industry[i] = 'Policy/Government/Social Work'
    else:
        industry[i] = 'Others'

# %%
industry
# Out:
# ['Education/Research',
#  'Education/Research',
#  'Healthcare',
#  'Consulting',
#  'Education/Research',
#  'Healthcare',
#  'Others',
#  'Others',
#  'Others',
#  'Education/Research',
#  'Healthcare',
#  'Others',
#  'Others',
#  'Charity/Volunteering',
#  'Others',
#  'Others',
#  'Healthcare',
#  'Healthcare',
#  'Education/Research',
#  'Healthcare',
#  'Others',
#  'Education/Research',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Business/Finance',
#  'Others',
#  'Business/Finance',
#  'Others',
#  'Technology',
#  'Healthcare',
#  'Healthcare',
#  'Technology',
#  'Business/Finance',
#  'Healthcare',
#  'Others',
#  'Others',
#  'Business/Finance',
#  'Consulting',
#  'Consulting',
#  'Consulting',
#  'Education/Research',
#  'Business/Finance',
#  'Others',
#  'Others',
#  'Others',
#  'Human Resources',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Healthcare',
#  'Others',
#  'Others',
#  'Healthcare',
#  'Others',
# ...

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(industry_true, industry))
# Out:
#                                precision    recall  f1-score   support
#
#              Business/Finance       0.16      0.17      0.17       332
#          Charity/Volunteering       0.08      0.03      0.05       149
#                    Consulting       0.00      0.00      0.00        43
#            Education/Research       0.17      0.16      0.16       447
#                    Healthcare       0.07      0.57      0.12        51
#               Human Resources       0.07      0.18      0.10        67
#                           Law       0.00      0.00      0.00       155
#                        Others       0.23      0.23      0.23       997
# Policy/Government/Social Work       0.06      0.01      0.01       166
#                    Technology       0.29      0.15      0.20       331
#
#                      accuracy                           0.17      2738
#                     macro avg       0.11      0.15      0.10      2738
# ...
